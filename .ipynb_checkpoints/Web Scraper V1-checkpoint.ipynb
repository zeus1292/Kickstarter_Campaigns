# %% [markdown]
# <h2> Read in the Data Frame </h2>

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
import json

# %%
kickstarter_df = pd.read_csv("Kickstarter001.csv")

# %%
kickstarter_df.head(5)
# Out:
#    backers_count                                              blurb  \
# 0             25  Provocative. Timeless.  This project symbolize...
# 1              5  Perfectly preserved herbs, for when fresh herb...
# 2              7  Live events centered around women. Poetry, mus...
# 3             15  The 2nd Annual MAC PAC Sponsored Exhibition fe...
# 4              1  Hour-long scripted drama TV pilot for a series...
#
#                                             category  \
# 0  {"id":39,"name":"Hip-Hop","slug":"music/hip-ho...
# 1  {"id":313,"name":"Small Batch","slug":"food/sm...
# 2  {"id":24,"name":"Performance Art","slug":"art/...
# 3  {"id":54,"name":"Mixed Media","slug":"art/mixe...
# 4  {"id":303,"name":"Television","slug":"film & v...
#
#    converted_pledged_amount country  created_at  \
# 0                      1547      US  1330517520
# 1                       152      CA  1454992401
# 2                       235      US  1461566342
# 3                      1710      US  1411352769
# 4                         1      US  1532815519
#
#                                              creator currency currency_symbol  \
# 0  {"id":41326882,"name":"Joshua Harris","is_regi...      USD               $
# 1  {"id":889915542,"name":"Dustin","is_registered...      CAD               $
# 2  {"id":384013732,"name":"Ciarra W","is_register...      USD               $
# 3  {"id":945877241,"name":"The McKinney Avenue Co...      USD               $
# 4  {"id":1176168309,"name":"Matt Borlenghi","is_r...      USD               $
#
#    currency_trailing_code  ...  \
# 0                    True  ...
# 1                    True  ...
# 2                    True  ...
# 3                    True  ...
# 4                    True  ...
#
#                                                 slug  \
# 0                                          the-vault
# 1                                 freeze-dried-herbs
# 2                                            toast-1
# 3  current-obsessions-an-exhibtion-by-christopher...
# 4                                                atf
#
#                                           source_url  spotlight staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...       True      False
# 1  https://www.kickstarter.com/discover/categorie...      False      False
# 2  https://www.kickstarter.com/discover/categorie...      False      False
# 3  https://www.kickstarter.com/discover/categorie...       True      False
# 4  https://www.kickstarter.com/discover/categorie...      False      False
#
#         state  state_changed_at  static_usd_rate  \
# 0  successful        1334301503         1.000000
# 1      failed        1466643321         0.774911
# 2      failed        1466028586         1.000000
# 3  successful        1415321110         1.000000
# 4      failed        1535419172         1.000000
#
#                                                 urls  usd_pledged  usd_type
# 0  {"web":{"project":"https://www.kickstarter.com...  1547.000000  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...   151.107737  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...   235.000000  domestic
# 3  {"web":{"project":"https://www.kickstarter.com...  1710.000000  domestic
# 4  {"web":{"project":"https://www.kickstarter.com...     1.000000  domestic
#
# [5 rows x 37 columns]

# %%
def extract_creator_id(json_obj):
    try:
        temp=json.loads(json_obj)
    except:
        return None
    return temp['id']
    
creator_id = kickstarter_df['creator'].apply(extract_creator_id)

# %%
def extract_reward_urls(json_obj):
    temp = json.loads(json_obj)
    return (temp['web']['rewards'])
    
reward_urls=kickstarter_df['urls'].apply(extract_reward_urls)

# %% [markdown]
# <h2> Runtime is pretty high for pull_reward_details (>60 mins for 3800 records) </h2>

# %%
def pull_reward_details(url_list):
    
    reward_tier = list()
    #Read the urls and extract details on rewarding tiers
    for i in url_list:
        #print(i)
        response=requests.get(i)
        if response.status_code!=200:
            print("Error pulling data from {}".format(i))
            continue
        reward_desc=bs(response.content,'lxml')
        a=reward_desc.find('ol').find_all('li')
        reward_tier.append(len(a))
    
    return (reward_tier)
        
reward_tier = pull_reward_details(reward_urls)

# %%
a = pd.DataFrame({"Project_Id":kickstarter_df['id'],"Creator_Id":creator_id,"Reward_Tiers":reward_tier,"Rewards_Url":reward_urls})

# %%
a
